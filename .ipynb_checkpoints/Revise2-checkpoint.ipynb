# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None

# %%
def cycleStart(head):   # Time - On, Space On
    hashMap = {}
    while head != None:
        if head in hashMap:
            return head
        else:
            hashMap[head] = 1
        head = head.next
    return None

def cycleStart(head):
    slow, fast = head, head
    while fast.next and fast.next.next:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
            break
    else:
        return None
    fast = head
    while True:
        if slow == fast:
            return slow
        slow = slow.next
        fast = fast.next

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        self.child = None

def mergeLL(head1,head2):
    dummy = Node(0)
    temp = dummy
    while head1 and head2:
        if head1.value > head2.value:
            dummy = head2
            head2 = head2.next
        else:
            dummy = head1
            head1 = head1.next
        dummy = dummy.next
    if head1 is None:
        dummy.next = head2
    else:
        dummy.next = head1
    return temp.next

def flattenLL(head):
    if head is None or head.next is None:
        return head
    flattenedList = flatten(head.next)
    currListFlattened = merge(head,flattenedList)
    return currListFlattened

# %%
def rotateLL(head,steps):
    if not head or steps == 0:
        return head
    lenLL = 0
    dummy = head
    while dummy != None:
        lenLL += 1
        dummy = dummy.next
    if steps % lenLL == 0:
        return head
    else:
        steps = steps % lenLL
    dummy = head
    for i in range(lenLL-steps):
        dummy = dummy.next
    newHead = dummy.next
    dummy.next = None
    dummy = newHead
    while dummy.next != None:
        dummy = dummy.next
    dummy.next = head
    return newHead

# %%
# !pip install jupyterthemes
# !jt -t chesterish

# %%
def nodesInLoop(head):
    slow, fast = head, head
    while fast.next and fast.next.next:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
            break
    else:
        return None
    slow = head
    while True:
        if slow == fast:
            break
        slow = slow.next
        fast = fast.next
    counter = 1
    slow = slow.next
    while slow != fast:
        slow = slow.next
        counter += 1
    return counter

# %%
class Node:
    def __init__(self,value):
        self.value = value
        self.next = None
        self.random = None

# %%
def cloneLL(head):
    if not head:
        return head
    tempHead = head
    while tempHead != None:
        clonedNode = Node(value)
        clonedNode.next = tempHead.next
        tempHead.next = clonedNode
        tempHead = tempHead.next.next
    tempHead = head
    while tempHead != None:
        if tempHead.random:
            tempHead.next.random = tempHead.random.next
        tempHead = tempHead.next.next
    dummy = Node(0)
    temp = dummy
    while head != None:
        dummy.next = head.next
        dummy = dummy.next
        head.next = head.next.head
    return temp
